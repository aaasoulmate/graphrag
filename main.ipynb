# %%
from zhipuai import ZhipuAI

# %%
api_key = '19e85ecfbb614aa88cfc4acc2957daf5.EmuxyGwyJp4AeLri'

client = ZhipuAI(api_key=api_key,
                base_url="https://open.bigmodel.cn/api/paas/v4")

response = client.chat.completions.create(
    model="glm-4-flash",
    messages=[
        {"role": "user", "content": "Please introduce yourself in short."}
    ]
)

print(response.choices[0].message.content)
# Out:
# Hello! I'm ChatGLM, an AI assistant based on the GLM model developed by Knowledge Engineering Group, Tsinghua University and Zhipu.AI. I have been trained to understand and respond to various types of questions proposed by users.

# %%
# !graphrag init --root ../ragtest0
# Out:
# Initializing project at /Users/dfl/Documents/ragtest0
# ⠋ GraphRAG Indexer

# %%
# !graphrag index --root ../ragtest0
# Out:
# Logging enabled at /Users/dfl/Documents/ragtest0/logs/indexing-engine.log
# 🚀 LLM Config Params Validated
# 🚀 Embedding LLM Config Params Validated
# Running standard indexing.
# ⠸ GraphRAG Indexer
# ⠸ GraphRAG Indexer e.text) - 1 files loaded (1 filtered) ━ 100% … 0…
# ⠸ GraphRAG Indexer e.text) - 1 files loaded (1 filtered) ━ 100% … 0…
# 🚀 create_base_text_unitses loaded (1 filtered) ━ 100% … 0…
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (1 filtered) ━ 100% … 0…
#                                                   id  ... n_tokens 0:00:00
# 0  1abaeec93a0e839705a3f0328981656d09a877f047ed55...  ...     1200
# 1  74283d24181a53d6e4874b6d505a3f2ef5a316fdbd835f...  ...     1200
# 2  c20bf32ab2ab7162bc5101355951a279cab6c6257d7036...  ...      477
#
# [3 rows x 4 columns]
# ⠼ GraphRAG Indexer
# ├── Loading Input (InputFileType.text) - 1 files loaded (1 filtered) ━ 100% … 0…
# ⠼ GraphRAG Indexer ━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00 0:00:00
# ...

# %%
# !graphrag query --root ../ragtest0 --method local --query "please introudce ID3 algorithm."
# Out:
# INFO: Vector Store Args: {
#     "default_vector_store": {
#         "type": "lancedb",
#         "db_uri": "/Users/dfl/Documents/ragtest0/output/lancedb",
#         "url": null,
#         "audience": null,
#         "container_name": "==== REDACTED ====",
#         "database_name": null,
#         "overwrite": true
#     }
# }
#
# SUCCESS: Local Search Response:
# The ID3 (Iterative Dichotomiser 3) algorithm is a foundational decision tree algorithm designed for classification problems, particularly those involving discrete variables. It operates by utilizing information gain as a criterion to determine the optimal feature for splitting the data. This approach enables the algorithm to construct decision trees that effectively categorize and classify the given data.
#
# ### Key Features of ID3:
#
# ...

# %%
# !graphrag query --root ../ragtest0 --method local --query "please compare ID3 and C4.5 arounf 60 words."
# Out:
# INFO: Vector Store Args: {
#     "default_vector_store": {
#         "type": "lancedb",
#         "db_uri": "/Users/dfl/Documents/ragtest0/output/lancedb",
#         "url": null,
#         "audience": null,
#         "container_name": "==== REDACTED ====",
#         "database_name": null,
#         "overwrite": true
#     }
# }
#
# SUCCESS: Local Search Response:
# ID3 and C4.5 are decision tree algorithms, but C4.5 is an extension of ID3. ID3 uses information gain and handles discrete variables, while C4.5 introduces information value and gain ratio for continuous variables, improving decision-making and reducing overfitting. C4.5 also incorporates pruning for better generalization.
